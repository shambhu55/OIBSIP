# %% [markdown]
# # Wine Quality Prediction

# %% [markdown]
# The "Wine Quality Prediction" project aims to predict the quality of wine based on its chemical attributes, such as density and acidity. The project uses machine learning classifier models Random Forest, Stochastic Gradient Descent, and Support Vector Classifier (SVC) to classify wine quality. Data manipulation is handled using Pandas, while Numpy is employed for array operations. Seaborn and Matplotlib are utilized to visualize patterns and gain insights into the dataset.

# %% [markdown]
# ## Loading Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Load dataset
data = pd.read_csv(r"C:\Users\HP\Desktop\Data Analytics\Sales_Inslight DA Project\WineQT.csv")

# %% [markdown]
# ## Data Preprocessing

# %%
#Data cleaning
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
data.info()  # Overview of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
data.isnull().sum()  # Check for missing values
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
# Separate features and target variable
X = data.drop('quality', axis=1)  # Features
y = data['quality']  # Target variable

# %%
# Standardizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Training and Evaluating Models

# %%
#model = RandomForestClassifier()
RandomForestClassifier().fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"{RandomForestClassifier} \n Performance:")
print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))
print("\n Classification Report: \n", classification_report(y_test, y_pred))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
#  Performance:
# Confusion Matrix:
#  [[ 0  3  3  0  0]
#  [ 0 74 21  1  0]
#  [ 0 25 68  6  0]
#  [ 0  0 11 15  0]
#  [ 0  0  2  0  0]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.73      0.77      0.75        96
#            6       0.65      0.69      0.67        99
#            7       0.68      0.58      0.62        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.69       229
#    macro avg       0.41      0.41      0.41       229
# weighted avg       0.66      0.69      0.67       229
# ...

# %%
SVC().fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"{SVC} \n Performance:")
print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))
print("\n Classification Report: \n", classification_report(y_test, y_pred))
# Out:
# <class 'sklearn.svm._classes.SVC'>
#  Performance:
# Confusion Matrix:
#  [[ 0  3  3  0  0]
#  [ 0 74 21  1  0]
#  [ 0 25 68  6  0]
#  [ 0  0 11 15  0]
#  [ 0  0  2  0  0]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.73      0.77      0.75        96
#            6       0.65      0.69      0.67        99
#            7       0.68      0.58      0.62        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.69       229
#    macro avg       0.41      0.41      0.41       229
# weighted avg       0.66      0.69      0.67       229
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
SGDClassifier().fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"{SGDClassifier} Performance:")
print("Confusion Matrix: \n", confusion_matrix(y_test, y_pred))
print("\n Classification Report: \n", classification_report(y_test, y_pred))
# Out:
# <class 'sklearn.linear_model._stochastic_gradient.SGDClassifier'> Performance:
# Confusion Matrix:
#  [[ 0  3  3  0  0]
#  [ 0 74 21  1  0]
#  [ 0 25 68  6  0]
#  [ 0  0 11 15  0]
#  [ 0  0  2  0  0]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.73      0.77      0.75        96
#            6       0.65      0.69      0.67        99
#            7       0.68      0.58      0.62        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.69       229
#    macro avg       0.41      0.41      0.41       229
# weighted avg       0.66      0.69      0.67       229
# ...

# %% [markdown]
# ## Visualizing patterns and insights

# %%
rf_model = RandomForestClassifier()  # Create the RandomForestClassifier instance

# Train the model
rf_model.fit(X_train, y_train)

# Get feature importances
importances = rf_model.feature_importances_

# Create a colormap that gets darker for higher values and lighter for lower values
colors = sns.color_palette("Blues", len(importances))  # "Blues" can be replaced with any sequential palette

# Sort the feature importances and their corresponding features for a better visual effect
sorted_idx = np.argsort(importances)  # Sort feature importances to make the plot more readable

# Visualize the feature importances with gradient color shading
plt.figure(figsize=(10,6))
sns.barplot(x=importances[sorted_idx], y=np.array(X.columns)[sorted_idx], palette="Blues_d")  # Use "Blues_d" for dark-to-light
plt.title("Feature Importance in Random Forest")
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18700\4240222132.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=importances[sorted_idx], y=np.array(X.columns)[sorted_idx], palette="Blues_d")  # Use "Blues_d" for dark-to-light

# %%
#Correlation matrix to visualize the relationships between chemical attributes
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Wine Features')
plt.show()

# %%
#Bar plot for Distribution of Wine Quality Ratings
sns.countplot(x='quality', data=data, palette='Set2')
plt.title('Distribution of Wine Quality Ratings')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18700\4079064135.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='quality', data=data, palette='Set2')

# %%
#Box plot for Alcohol Content Distribution by Wine Quality
plt.figure(figsize=(10,6))
sns.boxplot(x='quality', y='alcohol', data=data, palette='Blues')
plt.title('Alcohol Content Distribution by Wine Quality')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18700\193439657.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y='alcohol', data=data, palette='Blues')

# %%
#Violin plot for Residual Sugar Distribution by Wine Quality
plt.figure(figsize=(10,6))
sns.violinplot(x='quality', y='residual sugar', data=data, palette='muted')
plt.title('Residual Sugar Distribution by Wine Quality')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18700\1927107409.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='quality', y='residual sugar', data=data, palette='muted')

# %%
#Pairplot of Top Features and Wine Quality
top_features = ['alcohol', 'volatile acidity', 'residual sugar', 'quality']
sns.pairplot(data[top_features], hue='quality', palette='Set1')
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# By analyzing the wine's chemical features, the project successfully demonstrates how machine learning models can predict wine quality. Each classifier presents varying performance, with Random Forest often excelling in accuracy. The visualizations provide clear insights into how specific chemical properties influence wine quality, offering practical value in viticulture.
